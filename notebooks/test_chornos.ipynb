# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import torch

from chronos import BaseChronosPipeline

# %%
if torch.cuda.is_available():
    print(f"CUDA is available. Device: {torch.cuda.get_device_name(0)}")
else:
    print("CUDA is not available. Using CPU instead.")
# Out:
# CUDA is not available. Using CPU instead.

# %% [markdown]
# # Model Configuration
#
# Choose between loading a local model or downloading one from Hugging Face.

# %%
import tarfile
import os
from pathlib import Path

# ============================================================================
# CONFIGURATION: Choose your model source
# ============================================================================

# Set to 'local' or 'online'
MODEL_SOURCE = 'local'  # Change to 'online' to download from Hugging Face

# Available online models from Hugging Face
ONLINE_MODELS = {
    '1': 'amazon/chronos-bolt-tiny',
    '2': 'amazon/chronos-bolt-small',
    '3': 'amazon/chronos-bolt-base',
    '4': 'amazon/chronos-t5-tiny',
    '5': 'amazon/chronos-t5-small',
}


# For online models: choose by number (1-5) or set directlyprint(f"\nModel source: {MODEL_SOURCE.upper()}")

SELECTED_ONLINE_MODEL = '3'  # Default: chronos-bolt-baseprint("="*60)

print("🤖 CHRONOS MODEL LOADER")

# For local models: set the model path or choose interactively belowprint("="*60)

LOCAL_MODEL_PATH = '../models/base/chronos-bolt-tiny'  # Default local path

# ============================================================================
# Out:
# 🤖 CHRONOS MODEL LOADER

# %% [markdown]
# # Testing with Synthetic Time Series
#
# We will now test the Chronos model with different types of time series created with numpy.

# %%
# Seaborn style configuration
sns.set_style("whitegrid")
sns.set_palette("husl")

# General parameters
n_points = 100  # historical points
prediction_length = 20  # points to predict

# %% [markdown]
# ## 1. Linear Time Series (Trend)

# %%
# ============================================================================
# DISCOVER LOCAL MODELS
# ============================================================================

if MODEL_SOURCE == 'local':
    print("\n📁 Scanning for local models...\n")
    
    models_dir = Path('../models')
    
    # Find extracted model directories
    local_models = {}
    model_counter = 1
    
    # Search in common locations
    search_paths = [
        models_dir / 'base',
        models_dir / 'finne-tunned',
        models_dir / 'fine-tunned',
        models_dir / 'extracted',
        models_dir
    ]
    
    for search_path in search_paths:
        if search_path.exists():
            for item in search_path.iterdir():
                if item.is_dir():
                    # Check if it's a valid model directory
                    if (item / 'config.json').exists() or (item / 'model.safetensors').exists():
                        local_models[str(model_counter)] = str(item)
                        print(f"  {model_counter}. {item.name} ({item.parent.name}/{item.name})")
                        model_counter += 1
    
    # Find .tar.gz files
    print("\n📦 Available .tar.gz archives (need extraction):\n")
    tar_models = {}
    tar_counter = model_counter
    
    for tar_file in models_dir.rglob('*.tar.gz'):
        tar_models[str(tar_counter)] = str(tar_file)
        print(f"  {tar_counter}. {tar_file.name} (archived)")
        tar_counter += 1
    
    if not local_models and not tar_models:
        print("  ❌ No local models found!")
        print("\n💡 Tip: Place models in ../models/base/ or ../models/fine-tunned/")
    
    all_local_models = {**local_models, **tar_models}
    
    print(f"\n📌 Currently selected: {LOCAL_MODEL_PATH}")
    print("\n💡 To change selection, modify LOCAL_MODEL_PATH variable above or")
    print("   set it to one of the numbers shown.")

else:
    print("\n🌐 Available online models:\n")
    for key, model_name in ONLINE_MODELS.items():
        marker = "👉" if key == SELECTED_ONLINE_MODEL else "  "
        print(f"{marker} {key}. {model_name}")
    
    print(f"\n💡 To change selection, modify SELECTED_ONLINE_MODEL variable above.")
# Out:
# 📁 Scanning for local models...
#
#   1. chronos-bolt-tiny (base/chronos-bolt-tiny)
#   2. chronos-bolt-tiny (extracted/chronos-bolt-tiny)
#
# 📦 Available .tar.gz archives (need extraction):
#
#   3. base.tar.gz (archived)
#   4. chronos-bolt-tiny (1).tar.gz (archived)
#   5. chronos-bolt-tiny.tar.gz (archived)
#   6. chronos-bolt-tiny.tar.gz (archived)
#   7. chronos-bolt-tiny.tar.gz (archived)
#
# 📌 Currently selected: ../models/base/chronos-bolt-tiny
#
# 💡 To change selection, modify LOCAL_MODEL_PATH variable above or
#    set it to one of the numbers shown.

# %%
# ============================================================================
# EXTRACT TAR.GZ IF NEEDED
# ============================================================================

def extract_tar_model(tar_path: str) -> str:
    """Extract a .tar.gz model and return the path to the model directory."""
    extract_dir = Path('../models/extracted') / Path(tar_path).stem.replace('.tar', '')
    extract_dir.mkdir(parents=True, exist_ok=True)
    
    print(f"📦 Extracting {Path(tar_path).name}...")
    with tarfile.open(tar_path, 'r:gz') as tar:
        tar.extractall(path=extract_dir)
    
    # Find the model directory
    for root, dirs, files in os.walk(extract_dir):
        if 'config.json' in files or 'model.safetensors' in files:
            print(f"✅ Model extracted to: {root}")
            return root
    
    print(f"✅ Model extracted to: {extract_dir}")
    return str(extract_dir)

# Check if selected local model needs extraction
if MODEL_SOURCE == 'local':
    # Handle numeric selection
    if LOCAL_MODEL_PATH.isdigit() and LOCAL_MODEL_PATH in all_local_models:
        selected_path = all_local_models[LOCAL_MODEL_PATH]
        print(f"\n🎯 Using model #{LOCAL_MODEL_PATH}: {selected_path}")
        
        if selected_path.endswith('.tar.gz'):
            LOCAL_MODEL_PATH = extract_tar_model(selected_path)
        else:
            LOCAL_MODEL_PATH = selected_path
    
    # Check if current path is a tar.gz file
    elif LOCAL_MODEL_PATH.endswith('.tar.gz'):
        if os.path.exists(LOCAL_MODEL_PATH):
            LOCAL_MODEL_PATH = extract_tar_model(LOCAL_MODEL_PATH)
        else:
            print(f"\n⚠️ Warning: {LOCAL_MODEL_PATH} not found!")
    
    print(f"\n📂 Final model path: {LOCAL_MODEL_PATH}")
# Out:
# 📂 Final model path: ../models/base/chronos-bolt-tiny

# %%
# ============================================================================
# LOAD THE MODEL
# ============================================================================

print("\n" + "="*60)
print("⏳ Loading model...")
print("="*60)

try:
    if MODEL_SOURCE == 'local':
        print(f"📁 Loading local model from: {LOCAL_MODEL_PATH}")
        pipeline = BaseChronosPipeline.from_pretrained(
            LOCAL_MODEL_PATH,
            device_map="cpu",
            torch_dtype=torch.float32,
        )
        print(f"✅ Local model loaded successfully!")
        print(f"   Model path: {LOCAL_MODEL_PATH}")
    
    else:  # online
        model_name = ONLINE_MODELS.get(SELECTED_ONLINE_MODEL, ONLINE_MODELS['3'])
        print(f"🌐 Downloading model from Hugging Face: {model_name}")
        pipeline = BaseChronosPipeline.from_pretrained(
            model_name,
            device_map="cpu",
            torch_dtype=torch.float32,
        )
        print(f"✅ Online model loaded successfully!")
        print(f"   Model: {model_name}")
    
    print(f"   Type: {type(pipeline).__name__}")
    print("="*60)

except Exception as e:
    print(f"\n❌ Error loading model: {e}")
    print("\n💡 Troubleshooting tips:")
    if MODEL_SOURCE == 'local':
        print("   - Check that LOCAL_MODEL_PATH points to a valid model directory")
        print("   - Ensure the directory contains config.json and model files")
        print("   - Try extracting .tar.gz files first")
    else:
        print("   - Check your internet connection")
        print("   - Verify the model name is correct")
        print("   - Try a different model from the list")
    raise
# Out:
# ...
# ⏳ Loading model...
# ...
# 📁 Loading local model from: ../models/base/chronos-bolt-tiny
# ✅ Local model loaded successfully!
#    Model path: ../models/base/chronos-bolt-tiny
#    Type: ChronosBoltPipeline
# ...

# %%
# ============================================================================
# LOAD TEST DATA
# ============================================================================

df = pd.read_csv(
    "https://raw.githubusercontent.com/AileenNielsen/TimeSeriesAnalysisWithPython/master/data/AirPassengers.csv"
)

print(f"\n📊 Test data loaded: {len(df)} rows")
print(f"Columns: {list(df.columns)}")

# Test prediction with the loaded model
print("\n🧪 Running test prediction...")

quantiles, mean = pipeline.predict_quantiles(
    context=torch.tensor(df["#Passengers"], dtype=torch.float32),
    prediction_length=12,
    quantile_levels=[0.1, 0.5, 0.9],
)

print("✅ Test prediction successful!")
print(f"   Prediction shape: {quantiles.shape}")
print(f"   Predicted next 12 values (median): {quantiles[0, :, 1].numpy()[:5]}...")
# Out:
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# 📊 Test data loaded: 144 rows
# Columns: ['Month', '#Passengers']
#
# 🧪 Running test prediction...
# ✅ Test prediction successful!
#    Prediction shape: torch.Size([1, 12, 3])
#    Predicted next 12 values (median): [456.53928 469.48315 483.3252  493.48648 511.9297 ]...

# %%
# Create linear series
x_linear = np.arange(n_points)
y_linear = 2 * x_linear + 10 + np.random.normal(0, 5, n_points)

# Predict with Chronos
quantiles_linear, mean_linear = pipeline.predict_quantiles(
    context=torch.tensor(y_linear, dtype=torch.float32),
    prediction_length=prediction_length,
    quantile_levels=[0.1, 0.5, 0.9],
)

# Prepare data for visualization
forecast_index_linear = np.arange(n_points, n_points + prediction_length)
low_linear, median_linear, high_linear = (
    quantiles_linear[0, :, 0].numpy(),
    quantiles_linear[0, :, 1].numpy(),
    quantiles_linear[0, :, 2].numpy()
)

# Plot with seaborn
fig, ax = plt.subplots(figsize=(12, 5))
sns.lineplot(x=x_linear, y=y_linear, ax=ax, label="Historical data", linewidth=2)
sns.lineplot(x=forecast_index_linear, y=median_linear, ax=ax, label="Prediction (median)", 
             linewidth=2, linestyle='--')
ax.fill_between(forecast_index_linear, low_linear, high_linear, alpha=0.3, 
                label="80% interval")
ax.set_title("Linear Time Series - Chronos Prediction", fontsize=14, fontweight='bold')
ax.set_xlabel("Time")
ax.set_ylabel("Value")
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Sinusoidal Time Series

# %%
# Create sinusoidal series
x_sin = np.arange(n_points)
y_sin = 50 * np.sin(2 * np.pi * x_sin / 20) + 100 + np.random.normal(0, 5, n_points)

# Predict with Chronos
quantiles_sin, mean_sin = pipeline.predict_quantiles(
    context=torch.tensor(y_sin, dtype=torch.float32),
    prediction_length=prediction_length,
    quantile_levels=[0.1, 0.5, 0.9],
)

# Prepare data for visualization
forecast_index_sin = np.arange(n_points, n_points + prediction_length)
low_sin, median_sin, high_sin = (
    quantiles_sin[0, :, 0].numpy(),
    quantiles_sin[0, :, 1].numpy(),
    quantiles_sin[0, :, 2].numpy()
)

# Plot with seaborn
fig, ax = plt.subplots(figsize=(12, 5))
sns.lineplot(x=x_sin, y=y_sin, ax=ax, label="Historical data", linewidth=2)
sns.lineplot(x=forecast_index_sin, y=median_sin, ax=ax, label="Prediction (median)", 
             linewidth=2, linestyle='--')
ax.fill_between(forecast_index_sin, low_sin, high_sin, alpha=0.3, 
                label="80% interval")
ax.set_title("Sinusoidal Time Series - Chronos Prediction", fontsize=14, fontweight='bold')
ax.set_xlabel("Time")
ax.set_ylabel("Value")
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Sawtooth Time Series

# %%
# Create sawtooth series
x_saw = np.arange(n_points)
y_saw = 30 * (x_saw % 15) / 15 + 50 + np.random.normal(0, 3, n_points)

# Predict with Chronos
quantiles_saw, mean_saw = pipeline.predict_quantiles(
    context=torch.tensor(y_saw, dtype=torch.float32),
    prediction_length=prediction_length,
    quantile_levels=[0.1, 0.5, 0.9],
)

# Prepare data for visualization
forecast_index_saw = np.arange(n_points, n_points + prediction_length)
low_saw, median_saw, high_saw = (
    quantiles_saw[0, :, 0].numpy(),
    quantiles_saw[0, :, 1].numpy(),
    quantiles_saw[0, :, 2].numpy()
)

# Plot with seaborn
fig, ax = plt.subplots(figsize=(12, 5))
sns.lineplot(x=x_saw, y=y_saw, ax=ax, label="Historical data", linewidth=2)
sns.lineplot(x=forecast_index_saw, y=median_saw, ax=ax, label="Prediction (median)", 
             linewidth=2, linestyle='--')
ax.fill_between(forecast_index_saw, low_saw, high_saw, alpha=0.3, 
                label="80% interval")
ax.set_title("Sawtooth Time Series - Chronos Prediction", fontsize=14, fontweight='bold')
ax.set_xlabel("Time")
ax.set_ylabel("Value")
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Exponential Time Series

# %%
# Create exponential series
x_exp = np.arange(n_points)
y_exp = 10 * np.exp(0.02 * x_exp) + np.random.normal(0, 5, n_points)

# Predict with Chronos
quantiles_exp, mean_exp = pipeline.predict_quantiles(
    context=torch.tensor(y_exp, dtype=torch.float32),
    prediction_length=prediction_length,
    quantile_levels=[0.1, 0.5, 0.9],
)

# Prepare data for visualization
forecast_index_exp = np.arange(n_points, n_points + prediction_length)
low_exp, median_exp, high_exp = (
    quantiles_exp[0, :, 0].numpy(),
    quantiles_exp[0, :, 1].numpy(),
    quantiles_exp[0, :, 2].numpy()
)

# Plot with seaborn
fig, ax = plt.subplots(figsize=(12, 5))
sns.lineplot(x=x_exp, y=y_exp, ax=ax, label="Historical data", linewidth=2)
sns.lineplot(x=forecast_index_exp, y=median_exp, ax=ax, label="Prediction (median)", 
             linewidth=2, linestyle='--')
ax.fill_between(forecast_index_exp, low_exp, high_exp, alpha=0.3, 
                label="80% interval")
ax.set_title("Exponential Time Series - Chronos Prediction", fontsize=14, fontweight='bold')
ax.set_xlabel("Time")
ax.set_ylabel("Value")
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Time Series with Multiple Seasonality

# %%
# Create series with multiple seasonal components
x_multi = np.arange(n_points)
trend = 0.5 * x_multi
seasonal1 = 20 * np.sin(2 * np.pi * x_multi / 12)  # 12-period seasonality
seasonal2 = 10 * np.sin(2 * np.pi * x_multi / 30)  # 30-period seasonality
noise = np.random.normal(0, 5, n_points)
y_multi = trend + seasonal1 + seasonal2 + 100 + noise

# Predict with Chronos
quantiles_multi, mean_multi = pipeline.predict_quantiles(
    context=torch.tensor(y_multi, dtype=torch.float32),
    prediction_length=prediction_length,
    quantile_levels=[0.1, 0.5, 0.9],
)

# Prepare data for visualization
forecast_index_multi = np.arange(n_points, n_points + prediction_length)
low_multi, median_multi, high_multi = (
    quantiles_multi[0, :, 0].numpy(),
    quantiles_multi[0, :, 1].numpy(),
    quantiles_multi[0, :, 2].numpy()
)

# Plot with seaborn
fig, ax = plt.subplots(figsize=(12, 5))
sns.lineplot(x=x_multi, y=y_multi, ax=ax, label="Historical data", linewidth=2)
sns.lineplot(x=forecast_index_multi, y=median_multi, ax=ax, label="Prediction (median)", 
             linewidth=2, linestyle='--')
ax.fill_between(forecast_index_multi, low_multi, high_multi, alpha=0.3, 
                label="80% interval")
ax.set_title("Time Series with Multiple Seasonality - Chronos Prediction", 
             fontsize=14, fontweight='bold')
ax.set_xlabel("Time")
ax.set_ylabel("Value")
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Comparison of All Series
#
# Joint visualization of all time series and their predictions.

# %%
# Create a comparative visualization with subplots
fig, axes = plt.subplots(3, 2, figsize=(15, 12))
fig.suptitle('Comparison of Chronos Predictions on Different Time Series', 
             fontsize=16, fontweight='bold', y=1.00)

# Series 1: Linear
sns.lineplot(x=x_linear, y=y_linear, ax=axes[0, 0], label="Historical", linewidth=1.5)
sns.lineplot(x=forecast_index_linear, y=median_linear, ax=axes[0, 0], 
             label="Prediction", linewidth=1.5, linestyle='--')
axes[0, 0].fill_between(forecast_index_linear, low_linear, high_linear, alpha=0.3)
axes[0, 0].set_title("Linear", fontweight='bold')
axes[0, 0].set_xlabel("Time")
axes[0, 0].set_ylabel("Value")
axes[0, 0].legend()

# Series 2: Sinusoidal
sns.lineplot(x=x_sin, y=y_sin, ax=axes[0, 1], label="Historical", linewidth=1.5)
sns.lineplot(x=forecast_index_sin, y=median_sin, ax=axes[0, 1], 
             label="Prediction", linewidth=1.5, linestyle='--')
axes[0, 1].fill_between(forecast_index_sin, low_sin, high_sin, alpha=0.3)
axes[0, 1].set_title("Sinusoidal", fontweight='bold')
axes[0, 1].set_xlabel("Time")
axes[0, 1].set_ylabel("Value")
axes[0, 1].legend()

# Series 3: Sawtooth
sns.lineplot(x=x_saw, y=y_saw, ax=axes[1, 0], label="Historical", linewidth=1.5)
sns.lineplot(x=forecast_index_saw, y=median_saw, ax=axes[1, 0], 
             label="Prediction", linewidth=1.5, linestyle='--')
axes[1, 0].fill_between(forecast_index_saw, low_saw, high_saw, alpha=0.3)
axes[1, 0].set_title("Sawtooth", fontweight='bold')
axes[1, 0].set_xlabel("Time")
axes[1, 0].set_ylabel("Value")
axes[1, 0].legend()

# Series 4: Exponential
sns.lineplot(x=x_exp, y=y_exp, ax=axes[1, 1], label="Historical", linewidth=1.5)
sns.lineplot(x=forecast_index_exp, y=median_exp, ax=axes[1, 1], 
             label="Prediction", linewidth=1.5, linestyle='--')
axes[1, 1].fill_between(forecast_index_exp, low_exp, high_exp, alpha=0.3)
axes[1, 1].set_title("Exponential", fontweight='bold')
axes[1, 1].set_xlabel("Time")
axes[1, 1].set_ylabel("Value")
axes[1, 1].legend()

# Series 5: Multiple Seasonality
sns.lineplot(x=x_multi, y=y_multi, ax=axes[2, 0], label="Historical", linewidth=1.5)
sns.lineplot(x=forecast_index_multi, y=median_multi, ax=axes[2, 0], 
             label="Prediction", linewidth=1.5, linestyle='--')
axes[2, 0].fill_between(forecast_index_multi, low_multi, high_multi, alpha=0.3)
axes[2, 0].set_title("Multiple Seasonality", fontweight='bold')
axes[2, 0].set_xlabel("Time")
axes[2, 0].set_ylabel("Value")
axes[2, 0].legend()

# Series 6: AirPassengers (original)
sns.lineplot(x=range(len(df)), y=df["#Passengers"], ax=axes[2, 1], 
             label="Historical", linewidth=1.5)
sns.lineplot(x=forecast_index, y=median, ax=axes[2, 1], 
             label="Prediction", linewidth=1.5, linestyle='--')
axes[2, 1].fill_between(forecast_index, low, high, alpha=0.3)
axes[2, 1].set_title("AirPassengers (Real)", fontweight='bold')
axes[2, 1].set_xlabel("Time")
axes[2, 1].set_ylabel("Passengers")
axes[2, 1].legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 59
#      56 # Series 6: AirPassengers (original)
#      57 sns.lineplot(x=range(len(df)), y=df["#Passengers"], ax=axes[2, 1],
#      58              label="Historical", linewidth=1.5)
# ---> 59 sns.lineplot(x=forecast_index, y=median, ax=axes[2, 1],
#      60              label="Prediction", linewidth=1.5, linestyle='--')
#      61 axes[2, 1].fill_between(forecast_index, low, high, alpha=0.3)
#      62 axes[2, 1].set_title("AirPassengers (Real)", fontweight='bold')
#
# NameError: name 'forecast_index' is not defined
